# %%
from scipy.io import wavfile
import urllib
wavfile
#rate, x = wavfile.read("/Users/kristofer/anaconda3/lib/python3.7/site-packages/scipy/io/tests/data/test-44100Hz-2ch-32bit-float-le.wav")
link = "https://kozco.com/tech/piano2.wav"
f = urllib.request.urlopen(link)
urllib.request.urlretrieve (link, "test.wav")
rate, x = wavfile.read("test.wav")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-762d0e4d9607> in <module>
#       6 f = urllib.request.urlopen(link)
#       7 myfile = f.read()
# ----> 8 rate, x = wavfile.read(myfile)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/wavfile.py in read(filename, mmap)
#     231         mmap = False
#     232     else:
# --> 233         fid = open(filename, 'rb')
#     234
#     235     try:
#
# ValueError: embedded null byte

# %%
from matplotlib import pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(x);
#ax2.specgram(x);
